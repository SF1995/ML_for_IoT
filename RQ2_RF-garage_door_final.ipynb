# %%
# https://towardsdatascience.com/simple-logistic-regression-using-python-scikit-learn-86bf984f61f1

# %%
# import libraries and dataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.api.types import is_string_dtype, is_numeric_dtype

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
warnings.filterwarnings("ignore")
df = pd.read_csv("Train_Test_IoT_Garage_Door.csv")
df.head()
# Out:
#            ts       date        time door_state sphone_signal  label  type
# 0  1556228553  25-Apr-19   14:42:33      closed             0      1  ddos
# 1  1556228558  25-Apr-19   14:42:38      closed             0      1  ddos
# 2  1556228563  25-Apr-19   14:42:43      closed             0      1  ddos
# 3  1556228568  25-Apr-19   14:42:48      closed             0      1  ddos
# 4  1556228578  25-Apr-19   14:42:58      closed             0      1  ddos

# %%
# calculate duplicates 
dups = df.duplicated() 
# report if there are any duplicates 
print(dups.any()) 
# list all duplicate rows 
print(df[dups])
print(df.shape) 
# delete duplicate rows 
df.drop_duplicates(inplace=True) 
print(df.shape)
# Out:
# True
#                ts       date            time door_state sphone_signal  label  \
# 124    1556229495  25-Apr-19       14:58:15      closed             0      1
# 126    1556229500  25-Apr-19       14:58:20      closed             0      1
# 128    1556229505  25-Apr-19       14:58:25      closed             0      1
# 130    1556229510  25-Apr-19       14:58:30      closed             0      1
# 132    1556229515  25-Apr-19       14:58:35      closed             0      1
# ...           ...        ...             ...        ...           ...    ...
# 59582  1554203357   2-Apr-19     04:09:17        closed       false        0
# 59583  1554203357   2-Apr-19     04:09:17          open        true        0
# 59584  1554203357   2-Apr-19     04:09:17        closed       false        0
# 59585  1554203357   2-Apr-19     04:09:17        closed       false        0
# 59586  1554203357   2-Apr-19     04:09:17        closed       false        0
#
#          type
# 124      ddos
# 126      ddos
# 128      ddos
# 130      ddos
# 132      ddos
# ...       ...
# 59582  normal
# 59583  normal
# 59584  normal
# 59585  normal
# 59586  normal
#
# [38836 rows x 7 columns]
# (59587, 7)
# (20751, 7)

# %%
# address missing value
df.isnull().sum()
missing_count = df.isnull().sum() # the count of missing values
value_count = df.isnull().count() # the count of all values
missing_percentage = round(missing_count / value_count * 100, 1) #the percentage of missing values
missing_df = pd.DataFrame({'count': missing_count, 'percentage': missing_percentage}) #create a dataframe
print(missing_df)
# Out:
#                count  percentage
# ts                 0         0.0
# date               0         0.0
# time               0         0.0
# door_state         0         0.0
# sphone_signal      0         0.0
# label              0         0.0
# type               0         0.0

# %%
type('date')
# Out:
# str

# %%
type('time')
# Out:
# str

# %%
df['date'] = pd.to_datetime(df['date'])
print(df)
# Out:
#                ts       date            time door_state sphone_signal  label  \
# 0      1556228553 2019-04-25       14:42:33      closed             0      1
# 1      1556228558 2019-04-25       14:42:38      closed             0      1
# 2      1556228563 2019-04-25       14:42:43      closed             0      1
# 3      1556228568 2019-04-25       14:42:48      closed             0      1
# 4      1556228578 2019-04-25       14:42:58      closed             0      1
# ...           ...        ...             ...        ...           ...    ...
# 59307  1554203355 2019-04-02     04:09:15          open        true        0
# 59421  1554203356 2019-04-02     04:09:16        closed       false        0
# 59425  1554203356 2019-04-02     04:09:16          open        true        0
# 59566  1554203357 2019-04-02     04:09:17          open        true        0
# 59567  1554203357 2019-04-02     04:09:17        closed       false        0
#
#          type
# 0        ddos
# 1        ddos
# 2        ddos
# 3        ddos
# 4        ddos
# ...       ...
# 59307  normal
# 59421  normal
# 59425  normal
# 59566  normal
# 59567  normal
#
# [20751 rows x 7 columns]

# %%
dups = df.duplicated()

# %%
print(dups.any())
# Out:
# False

# %%
print(df[dups])
# Out:
# Empty DataFrame
# Columns: [ts, date, time, door_state, sphone_signal, label, type]
# Index: []

# %%
print(df.shape)
# Out:
# (20751, 7)

# %%
df.drop_duplicates(inplace=True)
print(df.shape)
# Out:
# (20751, 7)

# %%
#Transform string to date
df['date'] = pd.to_datetime(df.date, format="%d-%m-%Y")

# %%
#Extracting Year
df['year'] = df['date'].dt.year

#Extracting Month
df['month'] = df['date'].dt.month

#Extracting the weekday name of the date
df['day_name'] = df['date'].dt.day_name()

# %%
# dealing with attribute time
#new data frame with split value columns
new = df['time'].str.split(':',n=2,expand=True)

# %%
# making separate first name column from new data frame
df["hour"]= new[0]
df["min"]= new[1]
df["sec"]= new[2]

# %%
df['month'] = df['month'].astype(int)

# %%
df['hour'] = df['hour'].astype(int)

# %%
df['hour_sin'] = np.sin((df.hour-1)*(2.*np.pi/12))
df['hour_cos'] = np.cos((df.hour-1)*(2.*np.pi/12))

df['month_sin'] = np.sin((df.month-1)*(2.*np.pi/12))
df['month_cos'] = np.cos((df.month-1)*(2.*np.pi/12))

# %%
df
# Out:
#                ts       date            time door_state sphone_signal  label  \
# 0      1556228553 2019-04-25       14:42:33      closed             0      1
# 1      1556228558 2019-04-25       14:42:38      closed             0      1
# 2      1556228563 2019-04-25       14:42:43      closed             0      1
# 3      1556228568 2019-04-25       14:42:48      closed             0      1
# 4      1556228578 2019-04-25       14:42:58      closed             0      1
# ...           ...        ...             ...        ...           ...    ...
# 59307  1554203355 2019-04-02     04:09:15          open        true        0
# 59421  1554203356 2019-04-02     04:09:16        closed       false        0
# 59425  1554203356 2019-04-02     04:09:16          open        true        0
# 59566  1554203357 2019-04-02     04:09:17          open        true        0
# 59567  1554203357 2019-04-02     04:09:17        closed       false        0
#
#          type  year  month  day_name  hour min    sec  hour_sin      hour_cos  \
# 0        ddos  2019      4  Thursday    14  42    33        0.5  8.660254e-01
# 1        ddos  2019      4  Thursday    14  42    38        0.5  8.660254e-01
# 2        ddos  2019      4  Thursday    14  42    43        0.5  8.660254e-01
# 3        ddos  2019      4  Thursday    14  42    48        0.5  8.660254e-01
# 4        ddos  2019      4  Thursday    14  42    58        0.5  8.660254e-01
# ...       ...   ...    ...       ...   ...  ..    ...       ...           ...
# 59307  normal  2019      4   Tuesday     4  09  15          1.0  6.123234e-17
# 59421  normal  2019      4   Tuesday     4  09  16          1.0  6.123234e-17
# 59425  normal  2019      4   Tuesday     4  09  16          1.0  6.123234e-17
# 59566  normal  2019      4   Tuesday     4  09  17          1.0  6.123234e-17
# 59567  normal  2019      4   Tuesday     4  09  17          1.0  6.123234e-17
#
#        month_sin     month_cos
# 0            1.0  6.123234e-17
# 1            1.0  6.123234e-17
# 2            1.0  6.123234e-17
# 3            1.0  6.123234e-17
# 4            1.0  6.123234e-17
# ...          ...           ...
# 59307        1.0  6.123234e-17
# 59421        1.0  6.123234e-17
# 59425        1.0  6.123234e-17
# 59566        1.0  6.123234e-17
# 59567        1.0  6.123234e-17
#
# [20751 rows x 17 columns]

# %%
# address missing value
df.isnull().sum()
missing_count = df.isnull().sum() # the count of missing values
value_count = df.isnull().count() # the count of all values
missing_percentage = round(missing_count / value_count * 100, 1) #the percentage of missing values
missing_df = pd.DataFrame({'count': missing_count, 'percentage': missing_percentage}) #create a dataframe
print(missing_df)
# Out:
#                count  percentage
# ts                 0         0.0
# date               0         0.0
# time               0         0.0
# door_state         0         0.0
# sphone_signal      0         0.0
# label              0         0.0
# type               0         0.0
# year               0         0.0
# month              0         0.0
# day_name           0         0.0
# hour               0         0.0
# min                0         0.0
# sec                0         0.0
# hour_sin           0         0.0
# hour_cos           0         0.0
# month_sin          0         0.0
# month_cos          0         0.0

# %%
# drop columns 
df = df.drop(['ts', 'time','label','date','min','sec'], axis=1)

# %%
df
# Out:
#       door_state sphone_signal    type  year  month  day_name  hour  hour_sin  \
# 0         closed             0    ddos  2019      4  Thursday    14       0.5
# 1         closed             0    ddos  2019      4  Thursday    14       0.5
# 2         closed             0    ddos  2019      4  Thursday    14       0.5
# 3         closed             0    ddos  2019      4  Thursday    14       0.5
# 4         closed             0    ddos  2019      4  Thursday    14       0.5
# ...          ...           ...     ...   ...    ...       ...   ...       ...
# 59307       open        true    normal  2019      4   Tuesday     4       1.0
# 59421     closed       false    normal  2019      4   Tuesday     4       1.0
# 59425       open        true    normal  2019      4   Tuesday     4       1.0
# 59566       open        true    normal  2019      4   Tuesday     4       1.0
# 59567     closed       false    normal  2019      4   Tuesday     4       1.0
#
#            hour_cos  month_sin     month_cos
# 0      8.660254e-01        1.0  6.123234e-17
# 1      8.660254e-01        1.0  6.123234e-17
# 2      8.660254e-01        1.0  6.123234e-17
# 3      8.660254e-01        1.0  6.123234e-17
# 4      8.660254e-01        1.0  6.123234e-17
# ...             ...        ...           ...
# 59307  6.123234e-17        1.0  6.123234e-17
# 59421  6.123234e-17        1.0  6.123234e-17
# 59425  6.123234e-17        1.0  6.123234e-17
# 59566  6.123234e-17        1.0  6.123234e-17
# 59567  6.123234e-17        1.0  6.123234e-17
#
# [20751 rows x 11 columns]

# %%
# transform hour to int
df['hour'] = df['hour'].astype(int)

# %%
type('hour')
# Out:
# str

# %%
# transform int to string
# df['label'] = df['label'].astype(str)

# %%
df.sphone_signal.unique()
# Out:
# array(['0', '1', 'true  ', 'false  '], dtype=object)

# %%
df['sphone_signal'] = df['sphone_signal'].astype(str)

# %%
df.sphone_signal.replace(['true  ', 'false  '], ['1', '0'], inplace=True)

# %%
df.sphone_signal.unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
#df.type.replace(['normal','ddos','xss','backdoor','injection','password','ransomware','scanning' ], [0, 1, 2, 3, 4, 5, 6, 7], inplace=True)

# %%
# populate the numerical and categorical variables
num_list = []
cat_list = []
for column in df:
   if column != 'label': # separate lable
       if is_numeric_dtype(df[column]):
           num_list.append(column)
       elif is_string_dtype(df[column]):
           cat_list.append(column)

# %%
num_list
# Out:
# ['year', 'month', 'hour', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos']

# %%
cat_list
# Out:
# ['door_state', 'sphone_signal', 'type', 'day_name']

# %%
### 2. Feature Engineering and EDA  ###

# %%
# univariate analysis
for column in df:
   plt.figure(column, figsize = (5,5))
   plt.title(column)
   if is_numeric_dtype(df[column]):
       df[column].plot(kind = 'hist')
   elif is_string_dtype(df[column]):
       df[column].value_counts()[:10].plot(kind = 'bar')

# %%
df
# Out:
#       door_state sphone_signal    type  year  month  day_name  hour  hour_sin  \
# 0         closed             0    ddos  2019      4  Thursday    14       0.5
# 1         closed             0    ddos  2019      4  Thursday    14       0.5
# 2         closed             0    ddos  2019      4  Thursday    14       0.5
# 3         closed             0    ddos  2019      4  Thursday    14       0.5
# 4         closed             0    ddos  2019      4  Thursday    14       0.5
# ...          ...           ...     ...   ...    ...       ...   ...       ...
# 59307       open             1  normal  2019      4   Tuesday     4       1.0
# 59421     closed             0  normal  2019      4   Tuesday     4       1.0
# 59425       open             1  normal  2019      4   Tuesday     4       1.0
# 59566       open             1  normal  2019      4   Tuesday     4       1.0
# 59567     closed             0  normal  2019      4   Tuesday     4       1.0
#
#            hour_cos  month_sin     month_cos
# 0      8.660254e-01        1.0  6.123234e-17
# 1      8.660254e-01        1.0  6.123234e-17
# 2      8.660254e-01        1.0  6.123234e-17
# 3      8.660254e-01        1.0  6.123234e-17
# 4      8.660254e-01        1.0  6.123234e-17
# ...             ...        ...           ...
# 59307  6.123234e-17        1.0  6.123234e-17
# 59421  6.123234e-17        1.0  6.123234e-17
# 59425  6.123234e-17        1.0  6.123234e-17
# 59566  6.123234e-17        1.0  6.123234e-17
# 59567  6.123234e-17        1.0  6.123234e-17
#
# [20751 rows x 11 columns]

# %%
df['type'].value_counts()
# Out:
# backdoor      5000
# injection     3643
# password      3184
# ddos          3053
# ransomware    2774
# normal        1974
# xss            594
# scanning       529
# Name: type, dtype: int64

# %%
#from sklearn.preprocessing import LabelEncoder
#categorical_features = ['type']
#for i in categorical_features:
  # df[i] = LabelEncoder().fit_transform(df[i])

# %%
df['type'].value_counts()
# Out:
# backdoor      5000
# injection     3643
# password      3184
# ddos          3053
# ransomware    2774
# normal        1974
# xss            594
# scanning       529
# Name: type, dtype: int64

# %%
import category_encoders as ce
encoder= ce.BinaryEncoder(cols=['day_name', 'door_state','sphone_signal'],return_df=True)

# %%
df=encoder.fit_transform(df)

# %%
list(df.columns)
# Out:
# ['door_state_0',
#  'door_state_1',
#  'sphone_signal_0',
#  'sphone_signal_1',
#  'type',
#  'year',
#  'month',
#  'day_name_0',
#  'day_name_1',
#  'day_name_2',
#  'hour',
#  'hour_sin',
#  'hour_cos',
#  'month_sin',
#  'month_cos']

# %%
df
# Out:
#        door_state_0  door_state_1  sphone_signal_0  sphone_signal_1    type  \
# 0                 0             1                0                1    ddos
# 1                 0             1                0                1    ddos
# 2                 0             1                0                1    ddos
# 3                 0             1                0                1    ddos
# 4                 0             1                0                1    ddos
# ...             ...           ...              ...              ...     ...
# 59307             1             0                1                0  normal
# 59421             0             1                0                1  normal
# 59425             1             0                1                0  normal
# 59566             1             0                1                0  normal
# 59567             0             1                0                1  normal
#
#        year  month  day_name_0  day_name_1  day_name_2  hour  hour_sin  \
# 0      2019      4           0           0           1    14       0.5
# 1      2019      4           0           0           1    14       0.5
# 2      2019      4           0           0           1    14       0.5
# 3      2019      4           0           0           1    14       0.5
# 4      2019      4           0           0           1    14       0.5
# ...     ...    ...         ...         ...         ...   ...       ...
# 59307  2019      4           1           0           0     4       1.0
# 59421  2019      4           1           0           0     4       1.0
# 59425  2019      4           1           0           0     4       1.0
# 59566  2019      4           1           0           0     4       1.0
# 59567  2019      4           1           0           0     4       1.0
#
#            hour_cos  month_sin     month_cos
# 0      8.660254e-01        1.0  6.123234e-17
# 1      8.660254e-01        1.0  6.123234e-17
# 2      8.660254e-01        1.0  6.123234e-17
# 3      8.660254e-01        1.0  6.123234e-17
# 4      8.660254e-01        1.0  6.123234e-17
# ...             ...        ...           ...
# 59307  6.123234e-17        1.0  6.123234e-17
# 59421  6.123234e-17        1.0  6.123234e-17
# 59425  6.123234e-17        1.0  6.123234e-17
# 59566  6.123234e-17        1.0  6.123234e-17
# 59567  6.123234e-17        1.0  6.123234e-17
#
# [20751 rows x 15 columns]

# %%
# multivariate analysis
plt.figure(1, figsize = (15,15))
correlation = df.corr()
sns.heatmap(correlation, cmap = "GnBu", annot = True)
# Out:
# <AxesSubplot:>

# %%
# select and rearrange columns
df = df[['door_state_0',
 'door_state_1',
 'sphone_signal_0',
 'sphone_signal_1',
 'day_name_0',
 'day_name_1',
 'day_name_2',
 'hour_sin',
 'hour_cos',
 'month_sin',
 'month_cos', 'type']]

# %%
from sklearn.linear_model import LassoCV
from sklearn.model_selection import StratifiedKFold

X = df.iloc[:,:-1]
y = df["type"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt

X = df.iloc[:,:-1]
y = df["type"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
rf = RandomForestClassifier(n_estimators = 100, criterion='gini', random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
importances = rf.feature_importances_

indices = np.argsort(importances)

fig, ax = plt.subplots()
ax.barh(range(len(importances)), importances[indices])
ax.set_yticks(range(len(importances)))
_ = ax.set_yticklabels(np.array(X_train.columns)[indices])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from statistics import mean, stdev
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt
from sklearn import datasets


sfm = SelectFromModel(rf, threshold=0.05)
sfm.fit(X_train, y_train)
X_important_train = sfm.transform(X_train)
X_important_test = sfm.transform(X_test)
rf = RandomForestClassifier(n_estimators = 100, criterion='gini', random_state=42)
rf.fit(X_important_train, y_train)


y_pred = rf.predict(X_important_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     backdoor       1.00      0.53      0.69      1500
#         ddos       1.00      1.00      1.00       916
#    injection       1.00      1.00      1.00      1093
#       normal       1.00      1.00      1.00       592
#     password       1.00      1.00      1.00       956
#   ransomware       0.54      1.00      0.70       832
#     scanning       1.00      1.00      1.00       159
#          xss       1.00      1.00      1.00       178
#
#     accuracy                           0.89      6226
#    macro avg       0.94      0.94      0.92      6226
# weighted avg       0.94      0.89      0.89      6226
