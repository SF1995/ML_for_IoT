# %%
# import libraries and dataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.api.types import is_string_dtype, is_numeric_dtype

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
warnings.filterwarnings("ignore")
df = pd.read_csv("Train_Test_IoT_GPS_Tracker.csv")
df.head()
# Out:
#            ts       date        time    latitude   longitude  label  type
# 0  1556242299  25-Apr-19   18:31:39   116.521704  132.162504      1  ddos
# 1  1556242301  25-Apr-19   18:31:41   121.742933  135.072500      1  ddos
# 2  1556242306  25-Apr-19   18:31:46   121.795929  135.110198      1  ddos
# 3  1556242309  25-Apr-19   18:31:49   116.611216  132.224555      1  ddos
# 4  1556242311  25-Apr-19   18:31:51   121.841526  135.151362      1  ddos

# %%
# address missing value
df.isnull().sum()
missing_count = df.isnull().sum() # the count of missing values
value_count = df.isnull().count() # the count of all values
missing_percentage = round(missing_count / value_count * 100, 1) #the percentage of missing values
missing_df = pd.DataFrame({'count': missing_count, 'percentage': missing_percentage}) #create a dataframe
print(missing_df)
# Out:
#            count  percentage
# ts             0         0.0
# date           0         0.0
# time           0         0.0
# latitude       0         0.0
# longitude      0         0.0
# label          0         0.0
# type           0         0.0

# %%
# calculate duplicates 
dups = df.duplicated() 
# report if there are any duplicates 
print(dups.any()) 
# list all duplicate rows 
print(df[dups])
print(df.shape) 
# delete duplicate rows 
df.drop_duplicates(inplace=True) 
print(df.shape)
# Out:
# False
# Empty DataFrame
# Columns: [ts, date, time, latitude, longitude, label, type]
# Index: []
# (58960, 7)
# (58960, 7)

# %%
type('date')
# Out:
# str

# %%
type('time')
# Out:
# str

# %%
df['date'] = pd.to_datetime(df['date'])
print(df)
# Out:
#                ts       date        time    latitude   longitude  label  \
# 0      1556242299 2019-04-25   18:31:39   116.521704  132.162504      1
# 1      1556242301 2019-04-25   18:31:41   121.742933  135.072500      1
# 2      1556242306 2019-04-25   18:31:46   121.795929  135.110198      1
# 3      1556242309 2019-04-25   18:31:49   116.611216  132.224555      1
# 4      1556242311 2019-04-25   18:31:51   121.841526  135.151362      1
# ...           ...        ...         ...         ...         ...    ...
# 58955  1554202928 2019-04-02     4:02:08    1.028628   10.810522      0
# 58956  1554202928 2019-04-02     4:02:08    0.345361   10.727989      0
# 58957  1554202928 2019-04-02     4:02:08    0.423384   10.508036      0
# 58958  1554202928 2019-04-02     4:02:08    0.445292   10.381356      0
# 58959  1554202928 2019-04-02     4:02:08    0.532691   10.345983      0
#
#          type
# 0        ddos
# 1        ddos
# 2        ddos
# 3        ddos
# 4        ddos
# ...       ...
# 58955  normal
# 58956  normal
# 58957  normal
# 58958  normal
# 58959  normal
#
# [58960 rows x 7 columns]

# %%
#Transform string to date
df['date'] = pd.to_datetime(df.date, format="%d-%m-%Y")

# %%
#Extracting Year
df['year'] = df['date'].dt.year

#Extracting Month
df['month'] = df['date'].dt.month

#Extracting the weekday name of the date
df['day_name'] = df['date'].dt.day_name()

# %%
# dealing with attribute time
#new data frame with split value columns
new = df['time'].str.split(':',n=2,expand=True)

# %%
# making separate first name column from new data frame
df["hour"]= new[0]
df["min"]= new[1]
df["sec"]= new[2]

# %%
df['month'] = df['month'].astype(int)

# %%
df['hour'] = df['hour'].astype(int)

# %%
df.month.unique()
# Out:
# array([4, 3])

# %%
df.hour.unique()
# Out:
# array([18, 19,  8,  9, 10, 11, 12, 20, 21,  6,  7, 14, 15, 16, 13,  3,  4,
#         5, 22, 23, 17])

# %%
import numpy as np
df['hour_sin'] = np.sin((df.hour-1)*(2.*np.pi/24))
df['hour_cos'] = np.cos((df.hour-1)*(2.*np.pi/24))

df['month_sin'] = np.sin((df.month-1)*(2.*np.pi/12))
df['month_cos'] = np.cos((df.month-1)*(2.*np.pi/12))

# %%
df
# Out:
#                ts       date        time    latitude   longitude  label  \
# 0      1556242299 2019-04-25   18:31:39   116.521704  132.162504      1
# 1      1556242301 2019-04-25   18:31:41   121.742933  135.072500      1
# 2      1556242306 2019-04-25   18:31:46   121.795929  135.110198      1
# 3      1556242309 2019-04-25   18:31:49   116.611216  132.224555      1
# 4      1556242311 2019-04-25   18:31:51   121.841526  135.151362      1
# ...           ...        ...         ...         ...         ...    ...
# 58955  1554202928 2019-04-02     4:02:08    1.028628   10.810522      0
# 58956  1554202928 2019-04-02     4:02:08    0.345361   10.727989      0
# 58957  1554202928 2019-04-02     4:02:08    0.423384   10.508036      0
# 58958  1554202928 2019-04-02     4:02:08    0.445292   10.381356      0
# 58959  1554202928 2019-04-02     4:02:08    0.532691   10.345983      0
#
#          type  year  month  day_name  hour min  sec  hour_sin  hour_cos  \
# 0        ddos  2019      4  Thursday    18  31  39  -0.965926 -0.258819
# 1        ddos  2019      4  Thursday    18  31  41  -0.965926 -0.258819
# 2        ddos  2019      4  Thursday    18  31  46  -0.965926 -0.258819
# 3        ddos  2019      4  Thursday    18  31  49  -0.965926 -0.258819
# 4        ddos  2019      4  Thursday    18  31  51  -0.965926 -0.258819
# ...       ...   ...    ...       ...   ...  ..  ...       ...       ...
# 58955  normal  2019      4   Tuesday     4  02   08  0.707107  0.707107
# 58956  normal  2019      4   Tuesday     4  02   08  0.707107  0.707107
# 58957  normal  2019      4   Tuesday     4  02   08  0.707107  0.707107
# 58958  normal  2019      4   Tuesday     4  02   08  0.707107  0.707107
# 58959  normal  2019      4   Tuesday     4  02   08  0.707107  0.707107
#
#        month_sin     month_cos
# 0            1.0  6.123234e-17
# 1            1.0  6.123234e-17
# 2            1.0  6.123234e-17
# 3            1.0  6.123234e-17
# 4            1.0  6.123234e-17
# ...          ...           ...
# 58955        1.0  6.123234e-17
# 58956        1.0  6.123234e-17
# 58957        1.0  6.123234e-17
# 58958        1.0  6.123234e-17
# 58959        1.0  6.123234e-17
#
# [58960 rows x 17 columns]

# %%
# drop columns 
df = df.drop(['ts', 'time','label','date','min','sec','hour','month'], axis=1)

# %%
df
# Out:
#          latitude   longitude    type  year  day_name  hour_sin  hour_cos  \
# 0      116.521704  132.162504    ddos  2019  Thursday -0.965926 -0.258819
# 1      121.742933  135.072500    ddos  2019  Thursday -0.965926 -0.258819
# 2      121.795929  135.110198    ddos  2019  Thursday -0.965926 -0.258819
# 3      116.611216  132.224555    ddos  2019  Thursday -0.965926 -0.258819
# 4      121.841526  135.151362    ddos  2019  Thursday -0.965926 -0.258819
# ...           ...         ...     ...   ...       ...       ...       ...
# 58955    1.028628   10.810522  normal  2019   Tuesday  0.707107  0.707107
# 58956    0.345361   10.727989  normal  2019   Tuesday  0.707107  0.707107
# 58957    0.423384   10.508036  normal  2019   Tuesday  0.707107  0.707107
# 58958    0.445292   10.381356  normal  2019   Tuesday  0.707107  0.707107
# 58959    0.532691   10.345983  normal  2019   Tuesday  0.707107  0.707107
#
#        month_sin     month_cos
# 0            1.0  6.123234e-17
# 1            1.0  6.123234e-17
# 2            1.0  6.123234e-17
# 3            1.0  6.123234e-17
# 4            1.0  6.123234e-17
# ...          ...           ...
# 58955        1.0  6.123234e-17
# 58956        1.0  6.123234e-17
# 58957        1.0  6.123234e-17
# 58958        1.0  6.123234e-17
# 58959        1.0  6.123234e-17
#
# [58960 rows x 9 columns]

# %%
# transform hour to int
#df['hour'] = df['hour'].astype(int)

# %%
#type('hour')

# %%
# transform int to string
#df['label'] = df['label'].astype(str)

# %%
# populate the numerical and categorical variables
num_list = []
cat_list = []
for column in df:
   if column != 'label': # separate lable
       if is_numeric_dtype(df[column]):
           num_list.append(column)
       elif is_string_dtype(df[column]):
           cat_list.append(column)

# %%
num_list
# Out:
# ['latitude',
#  'longitude',
#  'year',
#  'hour_sin',
#  'hour_cos',
#  'month_sin',
#  'month_cos']

# %%
cat_list
# Out:
# ['type', 'day_name']

# %%
### 2. Feature Engineering and EDA  ###

# %%
# univariate analysis
for column in df:
   plt.figure(column, figsize = (5,5))
   plt.title(column)
   if is_numeric_dtype(df[column]):
       df[column].plot(kind = 'hist')
   elif is_string_dtype(df[column]):
       df[column].value_counts()[:10].plot(kind = 'bar')

# %%
df
# Out:
#          latitude   longitude    type  year  day_name  hour_sin  hour_cos  \
# 0      116.521704  132.162504    ddos  2019  Thursday -0.965926 -0.258819
# 1      121.742933  135.072500    ddos  2019  Thursday -0.965926 -0.258819
# 2      121.795929  135.110198    ddos  2019  Thursday -0.965926 -0.258819
# 3      116.611216  132.224555    ddos  2019  Thursday -0.965926 -0.258819
# 4      121.841526  135.151362    ddos  2019  Thursday -0.965926 -0.258819
# ...           ...         ...     ...   ...       ...       ...       ...
# 58955    1.028628   10.810522  normal  2019   Tuesday  0.707107  0.707107
# 58956    0.345361   10.727989  normal  2019   Tuesday  0.707107  0.707107
# 58957    0.423384   10.508036  normal  2019   Tuesday  0.707107  0.707107
# 58958    0.445292   10.381356  normal  2019   Tuesday  0.707107  0.707107
# 58959    0.532691   10.345983  normal  2019   Tuesday  0.707107  0.707107
#
#        month_sin     month_cos
# 0            1.0  6.123234e-17
# 1            1.0  6.123234e-17
# 2            1.0  6.123234e-17
# 3            1.0  6.123234e-17
# 4            1.0  6.123234e-17
# ...          ...           ...
# 58955        1.0  6.123234e-17
# 58956        1.0  6.123234e-17
# 58957        1.0  6.123234e-17
# 58958        1.0  6.123234e-17
# 58959        1.0  6.123234e-17
#
# [58960 rows x 9 columns]

# %%
df['type'].value_counts()
# Out:
# normal        35000
# ddos           5000
# backdoor       5000
# injection      5000
# password       5000
# ransomware     2833
# xss             577
# scanning        550
# Name: type, dtype: int64

# %%
# encoding categorical data using dummies
#from sklearn.preprocessing import LabelEncoder
#categorical_features = ['type']
#for i in categorical_features:
 #  df[i] = LabelEncoder().fit_transform(df[i])

# %%
df['type'].value_counts()
# Out:
# normal        35000
# ddos           5000
# backdoor       5000
# injection      5000
# password       5000
# ransomware     2833
# xss             577
# scanning        550
# Name: type, dtype: int64

# %%
import category_encoders as ce
encoder= ce.BinaryEncoder(cols=['day_name'],return_df=True)

# %%
df=encoder.fit_transform(df)

# %%
list(df.columns)
# Out:
# ['latitude',
#  'longitude',
#  'type',
#  'year',
#  'day_name_0',
#  'day_name_1',
#  'day_name_2',
#  'hour_sin',
#  'hour_cos',
#  'month_sin',
#  'month_cos']

# %%
df
# Out:
#          latitude   longitude    type  year  day_name_0  day_name_1  \
# 0      116.521704  132.162504    ddos  2019           0           0
# 1      121.742933  135.072500    ddos  2019           0           0
# 2      121.795929  135.110198    ddos  2019           0           0
# 3      116.611216  132.224555    ddos  2019           0           0
# 4      121.841526  135.151362    ddos  2019           0           0
# ...           ...         ...     ...   ...         ...         ...
# 58955    1.028628   10.810522  normal  2019           1           0
# 58956    0.345361   10.727989  normal  2019           1           0
# 58957    0.423384   10.508036  normal  2019           1           0
# 58958    0.445292   10.381356  normal  2019           1           0
# 58959    0.532691   10.345983  normal  2019           1           0
#
#        day_name_2  hour_sin  hour_cos  month_sin     month_cos
# 0               1 -0.965926 -0.258819        1.0  6.123234e-17
# 1               1 -0.965926 -0.258819        1.0  6.123234e-17
# 2               1 -0.965926 -0.258819        1.0  6.123234e-17
# 3               1 -0.965926 -0.258819        1.0  6.123234e-17
# 4               1 -0.965926 -0.258819        1.0  6.123234e-17
# ...           ...       ...       ...        ...           ...
# 58955           1  0.707107  0.707107        1.0  6.123234e-17
# 58956           1  0.707107  0.707107        1.0  6.123234e-17
# 58957           1  0.707107  0.707107        1.0  6.123234e-17
# 58958           1  0.707107  0.707107        1.0  6.123234e-17
# 58959           1  0.707107  0.707107        1.0  6.123234e-17
#
# [58960 rows x 11 columns]

# %%
# select and rearrange columns
df = df[['latitude',
 'longitude',
 'hour_sin',
 'hour_cos',
 'month_sin',
 'month_cos','day_name_0',
 'day_name_1',
 'day_name_2','type']]

# %%
df.columns
# Out:
# Index(['latitude', 'longitude', 'hour_sin', 'hour_cos', 'month_sin',
#        'month_cos', 'day_name_0', 'day_name_1', 'day_name_2', 'type'],
#       dtype='object')

# %%
#numerical variables for scaling
n = df.iloc[:,:-4]

# %%
n.head()
# Out:
#      latitude   longitude  hour_sin  hour_cos  month_sin     month_cos
# 0  116.521704  132.162504 -0.965926 -0.258819        1.0  6.123234e-17
# 1  121.742933  135.072500 -0.965926 -0.258819        1.0  6.123234e-17
# 2  121.795929  135.110198 -0.965926 -0.258819        1.0  6.123234e-17
# 3  116.611216  132.224555 -0.965926 -0.258819        1.0  6.123234e-17
# 4  121.841526  135.151362 -0.965926 -0.258819        1.0  6.123234e-17

# %%
from sklearn.preprocessing import RobustScaler
from sklearn import preprocessing

scaler = preprocessing.RobustScaler()
robust_df = scaler.fit_transform(n)
robust_df = pd.DataFrame(robust_df, columns =['latitude',
 'longitude',
 'hour_sin',
 'hour_cos',
 'month_sin',
 'month_cos'])

# %%
# scaled numerical features
robust_df
# Out:
#        latitude  longitude  hour_sin  hour_cos  month_sin  month_cos
# 0      1.468038   1.543287 -1.014612  0.858719        0.0        0.0
# 1      1.536471   1.581430 -1.014612  0.858719        0.0        0.0
# 2      1.537165   1.581924 -1.014612  0.858719        0.0        0.0
# 3      1.469212   1.544100 -1.014612  0.858719        0.0        0.0
# 4      1.537763   1.582463 -1.014612  0.858719        0.0        0.0
# ...         ...        ...       ...       ...        ...        ...
# 58955 -0.045682  -0.047337  0.371374  2.224745        0.0        0.0
# 58956 -0.054638  -0.048419  0.371374  2.224745        0.0        0.0
# 58957 -0.053615  -0.051302  0.371374  2.224745        0.0        0.0
# 58958 -0.053328  -0.052962  0.371374  2.224745        0.0        0.0
# 58959 -0.052182  -0.053426  0.371374  2.224745        0.0        0.0
#
# [58960 rows x 6 columns]

# %%
# extracting not scaled features (target feature + categorical features)
extracted_col= df[['day_name_0',
 'day_name_1',
 'day_name_2','type']]

# %%
# reset index
robust_df.reset_index(drop=True, inplace=True)
extracted_col.reset_index(drop=True, inplace=True)

# %%
standardized_df = robust_df.join(extracted_col)

# %%
# new dataframe, which is used for Logistic Regression
standardized_df
# Out:
#        latitude  longitude  hour_sin  hour_cos  month_sin  month_cos  \
# 0      1.468038   1.543287 -1.014612  0.858719        0.0        0.0
# 1      1.536471   1.581430 -1.014612  0.858719        0.0        0.0
# 2      1.537165   1.581924 -1.014612  0.858719        0.0        0.0
# 3      1.469212   1.544100 -1.014612  0.858719        0.0        0.0
# 4      1.537763   1.582463 -1.014612  0.858719        0.0        0.0
# ...         ...        ...       ...       ...        ...        ...
# 58955 -0.045682  -0.047337  0.371374  2.224745        0.0        0.0
# 58956 -0.054638  -0.048419  0.371374  2.224745        0.0        0.0
# 58957 -0.053615  -0.051302  0.371374  2.224745        0.0        0.0
# 58958 -0.053328  -0.052962  0.371374  2.224745        0.0        0.0
# 58959 -0.052182  -0.053426  0.371374  2.224745        0.0        0.0
#
#        day_name_0  day_name_1  day_name_2    type
# 0               0           0           1    ddos
# 1               0           0           1    ddos
# 2               0           0           1    ddos
# 3               0           0           1    ddos
# 4               0           0           1    ddos
# ...           ...         ...         ...     ...
# 58955           1           0           1  normal
# 58956           1           0           1  normal
# 58957           1           0           1  normal
# 58958           1           0           1  normal
# 58959           1           0           1  normal
#
# [58960 rows x 10 columns]

# %%
#extracted_col = df['label']
#print("column to added from first dataframe to second:")
#display(extracted_col)
  
#standardized_df = robust_df.join(extracted_col)
#print("Second dataframe after adding column from first dataframe:")
#display(standardized_df)

# %%
from sklearn.linear_model import LassoCV
#from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import StratifiedKFold

X = standardized_df.iloc[:,:-1]
y = standardized_df["type"]
#skf = StratifiedKFold(n_splits=10)
#lasso = LassoCV(cv=skf, random_state=42).fit(X, y)
#print('Selected Features:', list(df.columns[np.where(lasso.coef_!=0)[0]]))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from statistics import mean, stdev
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn import metrics
 
from sklearn.linear_model import LassoCV
from sklearn.model_selection import StratifiedKFold

X = standardized_df.iloc[:,:-1]
y = standardized_df["type"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)



lr = LogisticRegression(penalty='l1',C=1, solver='liblinear', max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)



#skf = StratifiedKFold(n_splits=10)
#lasso = LassoCV(cv=skf, random_state=42).fit(X, y)
#print('Selected Features:', list(standardized_df.columns[np.where(lasso.coef_!=0)[0]]))

#from sklearn.linear_model import LogisticRegression
#from sklearn.model_selection import cross_val_predict
#from sklearn.metrics import classification_report

#lr = LogisticRegression(penalty='l1',C=1, class_weight='balanced', max_iter=10000, random_state=42)
#preds = cross_val_predict(lr, X.iloc[:, np.where(lasso.coef_!=0)[0]], y, cv=skf)
#print(classification_report(y, preds))

# %%
from sklearn import metrics

# confusion matrix
confusion_matrix = metrics.plot_confusion_matrix(lr, X_test, y_test, cmap = "GnBu")
print(confusion_matrix)

# accuracy
print(classification_report(y_test, y_pred))
# Out:
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x0000021EA4E2DB20>
#               precision    recall  f1-score   support
#
#     backdoor       1.00      1.00      1.00      1500
#         ddos       1.00      1.00      1.00      1500
#    injection       1.00      1.00      1.00      1500
#       normal       1.00      1.00      1.00     10500
#     password       1.00      1.00      1.00      1500
#   ransomware       1.00      1.00      1.00       850
#     scanning       1.00      1.00      1.00       165
#          xss       1.00      1.00      1.00       173
#
#     accuracy                           1.00     17688
#    macro avg       1.00      1.00      1.00     17688
# weighted avg       1.00      1.00      1.00     17688

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [50], in <cell line: 7>()
#       5 from sklearn import preprocessing
#       6 X = df.iloc[:,:-1]
# ----> 7 y = df["label"]
#       8 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0, stratify=y)
#       9 print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'label'
