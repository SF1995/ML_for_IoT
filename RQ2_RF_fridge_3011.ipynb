# %%
# https://towardsdatascience.com/simple-logistic-regression-using-python-scikit-learn-86bf984f61f1

# %%
# import libraries and dataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.api.types import is_string_dtype, is_numeric_dtype

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
warnings.filterwarnings("ignore")
df = pd.read_csv("Train_Test_IoT_Fridge.csv")
df.head()
# Out:
#            ts       date        time  fridge_temperature temp_condition  \
# 0  1556245180  25-Apr-19   19:19:40                 9.00           high
# 1  1556245180  25-Apr-19   19:19:40                 9.25           high
# 2  1556245185  25-Apr-19   19:19:45                12.65           high
# 3  1556245185  25-Apr-19   19:19:45                 4.65            low
# 4  1556245195  25-Apr-19   19:19:55                12.65           high
#
#    label  type
# 0      1  ddos
# 1      1  ddos
# 2      1  ddos
# 3      1  ddos
# 4      1  ddos

# %%
# calculate duplicates 
dups = df.duplicated() 
# report if there are any duplicates 
print(dups.any()) 
# list all duplicate rows 
print(df[dups])
print(df.shape) 
# delete duplicate rows 
df.drop_duplicates(inplace=True) 
print(df.shape)
# Out:
# True
#                ts       date            time  fridge_temperature  \
# 59     1556245360  25-Apr-19       19:22:40                 3.20
# 157    1556245775  25-Apr-19       19:29:35                 1.00
# 237    1556246026  25-Apr-19       19:33:46                 2.00
# 281    1556246171  25-Apr-19       19:36:11                 6.25
# 289    1556246196  25-Apr-19       19:36:36                 8.65
# ...           ...        ...             ...                 ...
# 59929  1554203235   2-Apr-19     04:07:15                   7.50
# 59932  1554203235   2-Apr-19     04:07:15                   4.00
# 59934  1554203235   2-Apr-19     04:07:15                   2.00
# 59936  1554203235   2-Apr-19     04:07:15                  12.95
# 59939  1554203235   2-Apr-19     04:07:15                   7.65
#
#       temp_condition  label    type
# 59               low      1    ddos
# 157              low      1    ddos
# 237              low      1    ddos
# 281             high      1    ddos
# 289             high      1    ddos
# ...              ...    ...     ...
# 59929         high        0  normal
# 59932          low        0  normal
# 59934          low        0  normal
# 59936         high        0  normal
# 59939         high        0  normal
#
# [8901 rows x 7 columns]
# (59944, 7)
# (51043, 7)

# %%
# address missing value
df.isnull().sum()
missing_count = df.isnull().sum() # the count of missing values
value_count = df.isnull().count() # the count of all values
missing_percentage = round(missing_count / value_count * 100, 1) #the percentage of missing values
missing_df = pd.DataFrame({'count': missing_count, 'percentage': missing_percentage}) #create a dataframe
print(missing_df)
# Out:
#                     count  percentage
# ts                      0         0.0
# date                    0         0.0
# time                    0         0.0
# fridge_temperature      0         0.0
# temp_condition          0         0.0
# label                   0         0.0
# type                    0         0.0

# %%
type('date')
# Out:
# str

# %%
type('time')
# Out:
# str

# %%
df['date'] = pd.to_datetime(df['date'])
print(df)
# Out:
#                ts       date            time  fridge_temperature  \
# 0      1556245180 2019-04-25       19:19:40                 9.00
# 1      1556245180 2019-04-25       19:19:40                 9.25
# 2      1556245185 2019-04-25       19:19:45                12.65
# 3      1556245185 2019-04-25       19:19:45                 4.65
# 4      1556245195 2019-04-25       19:19:55                12.65
# ...           ...        ...             ...                 ...
# 59938  1554203235 2019-04-02     04:07:15                   9.85
# 59940  1554203235 2019-04-02     04:07:15                  13.85
# 59941  1554203235 2019-04-02     04:07:15                   5.40
# 59942  1554203235 2019-04-02     04:07:15                   2.90
# 59943  1554203235 2019-04-02     04:07:15                   7.85
#
#       temp_condition  label    type
# 0               high      1    ddos
# 1               high      1    ddos
# 2               high      1    ddos
# 3                low      1    ddos
# 4               high      1    ddos
# ...              ...    ...     ...
# 59938         high        0  normal
# 59940         high        0  normal
# 59941          low        0  normal
# 59942          low        0  normal
# 59943         high        0  normal
#
# [51043 rows x 7 columns]

# %%
#Transform string to date
df['date'] = pd.to_datetime(df.date, format="%d-%m-%Y")

# %%
#Extracting Year
df['year'] = df['date'].dt.year

#Extracting Month
df['month'] = df['date'].dt.month

#Extracting the weekday name of the date
df['day_name'] = df['date'].dt.day_name()

# %%
# dealing with attribute time
#new data frame with split value columns
new = df['time'].str.split(':',n=2,expand=True)

# %%
# making separate first name column from new data frame
df["hour"]= new[0]
df["min"]= new[1]
df["sec"]= new[2]

# %%
df['month'] = df['month'].astype(int)

# %%
df['hour'] = df['hour'].astype(int)

# %%
df.month.unique()
# Out:
# array([4, 3])

# %%
df.hour.unique()
# Out:
# array([19, 14, 15,  6,  7,  8, 12, 20, 21,  0,  1, 16, 17,  9, 18,  4, 13,
#         3,  5])

# %%
df['hour_sin'] = np.sin((df.hour-1)*(2.*np.pi/24))
df['hour_cos'] = np.cos((df.hour-1)*(2.*np.pi/24))

df['month_sin'] = np.sin((df.month-1)*(2.*np.pi/12))
df['month_cos'] = np.cos((df.month-1)*(2.*np.pi/12))

# %%
df
# Out:
#                ts       date            time  fridge_temperature  \
# 0      1556245180 2019-04-25       19:19:40                 9.00
# 1      1556245180 2019-04-25       19:19:40                 9.25
# 2      1556245185 2019-04-25       19:19:45                12.65
# 3      1556245185 2019-04-25       19:19:45                 4.65
# 4      1556245195 2019-04-25       19:19:55                12.65
# ...           ...        ...             ...                 ...
# 59938  1554203235 2019-04-02     04:07:15                   9.85
# 59940  1554203235 2019-04-02     04:07:15                  13.85
# 59941  1554203235 2019-04-02     04:07:15                   5.40
# 59942  1554203235 2019-04-02     04:07:15                   2.90
# 59943  1554203235 2019-04-02     04:07:15                   7.85
#
#       temp_condition  label    type  year  month  day_name  hour min    sec  \
# 0               high      1    ddos  2019      4  Thursday    19  19    40
# 1               high      1    ddos  2019      4  Thursday    19  19    40
# 2               high      1    ddos  2019      4  Thursday    19  19    45
# 3                low      1    ddos  2019      4  Thursday    19  19    45
# 4               high      1    ddos  2019      4  Thursday    19  19    55
# ...              ...    ...     ...   ...    ...       ...   ...  ..    ...
# 59938         high        0  normal  2019      4   Tuesday     4  07  15
# 59940         high        0  normal  2019      4   Tuesday     4  07  15
# 59941          low        0  normal  2019      4   Tuesday     4  07  15
# 59942          low        0  normal  2019      4   Tuesday     4  07  15
# 59943         high        0  normal  2019      4   Tuesday     4  07  15
#
#        hour_sin      hour_cos  month_sin     month_cos
# 0     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 1     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 2     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 3     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 4     -1.000000 -1.836970e-16        1.0  6.123234e-17
# ...         ...           ...        ...           ...
# 59938  0.707107  7.071068e-01        1.0  6.123234e-17
# 59940  0.707107  7.071068e-01        1.0  6.123234e-17
# 59941  0.707107  7.071068e-01        1.0  6.123234e-17
# 59942  0.707107  7.071068e-01        1.0  6.123234e-17
# 59943  0.707107  7.071068e-01        1.0  6.123234e-17
#
# [51043 rows x 17 columns]

# %%
# address missing value
df.isnull().sum()
missing_count = df.isnull().sum() # the count of missing values
value_count = df.isnull().count() # the count of all values
missing_percentage = round(missing_count / value_count * 100, 1) #the percentage of missing values
missing_df = pd.DataFrame({'count': missing_count, 'percentage': missing_percentage}) #create a dataframe
print(missing_df)
# Out:
#                     count  percentage
# ts                      0         0.0
# date                    0         0.0
# time                    0         0.0
# fridge_temperature      0         0.0
# temp_condition          0         0.0
# label                   0         0.0
# type                    0         0.0
# year                    0         0.0
# month                   0         0.0
# day_name                0         0.0
# hour                    0         0.0
# min                     0         0.0
# sec                     0         0.0
# hour_sin                0         0.0
# hour_cos                0         0.0
# month_sin               0         0.0
# month_cos               0         0.0

# %%
# drop columns 
df = df.drop(['ts', 'time','label','date','min','sec'], axis=1)

# %%
df
# Out:
#        fridge_temperature temp_condition    type  year  month  day_name  hour  \
# 0                    9.00           high    ddos  2019      4  Thursday    19
# 1                    9.25           high    ddos  2019      4  Thursday    19
# 2                   12.65           high    ddos  2019      4  Thursday    19
# 3                    4.65            low    ddos  2019      4  Thursday    19
# 4                   12.65           high    ddos  2019      4  Thursday    19
# ...                   ...            ...     ...   ...    ...       ...   ...
# 59938                9.85         high    normal  2019      4   Tuesday     4
# 59940               13.85         high    normal  2019      4   Tuesday     4
# 59941                5.40          low    normal  2019      4   Tuesday     4
# 59942                2.90          low    normal  2019      4   Tuesday     4
# 59943                7.85         high    normal  2019      4   Tuesday     4
#
#        hour_sin      hour_cos  month_sin     month_cos
# 0     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 1     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 2     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 3     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 4     -1.000000 -1.836970e-16        1.0  6.123234e-17
# ...         ...           ...        ...           ...
# 59938  0.707107  7.071068e-01        1.0  6.123234e-17
# 59940  0.707107  7.071068e-01        1.0  6.123234e-17
# 59941  0.707107  7.071068e-01        1.0  6.123234e-17
# 59942  0.707107  7.071068e-01        1.0  6.123234e-17
# 59943  0.707107  7.071068e-01        1.0  6.123234e-17
#
# [51043 rows x 11 columns]

# %%
# transform hour to int
df['hour'] = df['hour'].astype(int)

# %%
type('hour')
# Out:
# str

# %%
# transform int to string
#df['label'] = df['label'].astype(str)

# %%
df.temp_condition.unique()
# Out:
# array(['high', 'low', 'high ', 'low ', 'low  ', 'high  '], dtype=object)

# %%
df.temp_condition.replace(['high ', 'low ', 'low  ', 'high  '], ['high','low','low','high'], inplace=True)

# %%
df.temp_condition.unique()
# Out:
# array(['high', 'low'], dtype=object)

# %%
# populate the numerical and categorical variables
num_list = []
cat_list = []
for column in df:
   if column != 'label': # separate lable
       if is_numeric_dtype(df[column]):
           num_list.append(column)
       elif is_string_dtype(df[column]):
           cat_list.append(column)

# %%
num_list
# Out:
# ['fridge_temperature',
#  'year',
#  'month',
#  'hour',
#  'hour_sin',
#  'hour_cos',
#  'month_sin',
#  'month_cos']

# %%
cat_list
# Out:
# ['temp_condition', 'type', 'day_name']

# %%
### 2. Feature Engineering and EDA  ###

# %%
# univariate analysis
for column in df:
   plt.figure(column, figsize = (5,5))
   plt.title(column)
   if is_numeric_dtype(df[column]):
       df[column].plot(kind = 'hist')
   elif is_string_dtype(df[column]):
       df[column].value_counts()[:10].plot(kind = 'bar')

# %%
df
# Out:
#        fridge_temperature temp_condition    type  year  month  day_name  hour  \
# 0                    9.00           high    ddos  2019      4  Thursday    19
# 1                    9.25           high    ddos  2019      4  Thursday    19
# 2                   12.65           high    ddos  2019      4  Thursday    19
# 3                    4.65            low    ddos  2019      4  Thursday    19
# 4                   12.65           high    ddos  2019      4  Thursday    19
# ...                   ...            ...     ...   ...    ...       ...   ...
# 59938                9.85           high  normal  2019      4   Tuesday     4
# 59940               13.85           high  normal  2019      4   Tuesday     4
# 59941                5.40            low  normal  2019      4   Tuesday     4
# 59942                2.90            low  normal  2019      4   Tuesday     4
# 59943                7.85           high  normal  2019      4   Tuesday     4
#
#        hour_sin      hour_cos  month_sin     month_cos
# 0     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 1     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 2     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 3     -1.000000 -1.836970e-16        1.0  6.123234e-17
# 4     -1.000000 -1.836970e-16        1.0  6.123234e-17
# ...         ...           ...        ...           ...
# 59938  0.707107  7.071068e-01        1.0  6.123234e-17
# 59940  0.707107  7.071068e-01        1.0  6.123234e-17
# 59941  0.707107  7.071068e-01        1.0  6.123234e-17
# 59942  0.707107  7.071068e-01        1.0  6.123234e-17
# 59943  0.707107  7.071068e-01        1.0  6.123234e-17
#
# [51043 rows x 11 columns]

# %%
df['type'].value_counts()
# Out:
# normal        26215
# backdoor       5000
# injection      4975
# password       4972
# ddos           4964
# ransomware     2900
# xss            2017
# Name: type, dtype: int64

# %%
# encoding categorical data using dummies
#from sklearn.preprocessing import LabelEncoder
#categorical_features = ['type']
#for i in categorical_features:
 #  df[i] = LabelEncoder().fit_transform(df[i])

# %%
df['type'].value_counts()
# Out:
# normal        26215
# backdoor       5000
# injection      4975
# password       4972
# ddos           4964
# ransomware     2900
# xss            2017
# Name: type, dtype: int64

# %%
import category_encoders as ce
encoder= ce.BinaryEncoder(cols=['day_name'],return_df=True)

# %%
df=encoder.fit_transform(df)

# %%
from category_encoders import OrdinalEncoder 
maplist = [{'col': 'temp_condition', 'mapping': {'low': 0, 'high': 1}}]
oe = OrdinalEncoder(mapping=maplist)

# %%
df=oe.fit_transform(df)

# %%
df
# Out:
#        fridge_temperature  temp_condition    type  year  month  day_name_0  \
# 0                    9.00               1    ddos  2019      4           0
# 1                    9.25               1    ddos  2019      4           0
# 2                   12.65               1    ddos  2019      4           0
# 3                    4.65               0    ddos  2019      4           0
# 4                   12.65               1    ddos  2019      4           0
# ...                   ...             ...     ...   ...    ...         ...
# 59938                9.85               1  normal  2019      4           1
# 59940               13.85               1  normal  2019      4           1
# 59941                5.40               0  normal  2019      4           1
# 59942                2.90               0  normal  2019      4           1
# 59943                7.85               1  normal  2019      4           1
#
#        day_name_1  day_name_2  hour  hour_sin      hour_cos  month_sin  \
# 0               0           1    19 -1.000000 -1.836970e-16        1.0
# 1               0           1    19 -1.000000 -1.836970e-16        1.0
# 2               0           1    19 -1.000000 -1.836970e-16        1.0
# 3               0           1    19 -1.000000 -1.836970e-16        1.0
# 4               0           1    19 -1.000000 -1.836970e-16        1.0
# ...           ...         ...   ...       ...           ...        ...
# 59938           0           0     4  0.707107  7.071068e-01        1.0
# 59940           0           0     4  0.707107  7.071068e-01        1.0
# 59941           0           0     4  0.707107  7.071068e-01        1.0
# 59942           0           0     4  0.707107  7.071068e-01        1.0
# 59943           0           0     4  0.707107  7.071068e-01        1.0
#
#           month_cos
# 0      6.123234e-17
# 1      6.123234e-17
# 2      6.123234e-17
# 3      6.123234e-17
# 4      6.123234e-17
# ...             ...
# 59938  6.123234e-17
# 59940  6.123234e-17
# 59941  6.123234e-17
# 59942  6.123234e-17
# 59943  6.123234e-17
#
# [51043 rows x 13 columns]

# %%
list(df.columns)
# Out:
# ['fridge_temperature',
#  'temp_condition',
#  'type',
#  'year',
#  'month',
#  'day_name_0',
#  'day_name_1',
#  'day_name_2',
#  'hour',
#  'hour_sin',
#  'hour_cos',
#  'month_sin',
#  'month_cos']

# %%
# multivariate analysis
plt.figure(1, figsize = (15,15))
correlation = df.corr()
sns.heatmap(correlation, cmap = "GnBu", annot = True)
# Out:
# <AxesSubplot:>

# %%
# select and rearrange columns
df = df[['month_cos','month_sin','hour_sin','hour_cos','fridge_temperature','temp_condition',
 'temp_condition','day_name_0',
 'day_name_1',
 'day_name_2','type']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt

X = df.iloc[:,:-1]
y = df["type"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
rf = RandomForestClassifier(n_estimators = 100, criterion='gini', random_state=42)
rf.fit(X_train, y_train)

importances = rf.feature_importances_

indices = np.argsort(importances)

fig, ax = plt.subplots()
ax.barh(range(len(importances)), importances[indices])
ax.set_yticks(range(len(importances)))
_ = ax.set_yticklabels(np.array(X_train.columns)[indices])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from statistics import mean, stdev
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt
from sklearn import datasets


sfm = SelectFromModel(rf, threshold=0.05)
sfm.fit(X_train, y_train)
X_important_train = sfm.transform(X_train)
X_important_test = sfm.transform(X_test)
rf = RandomForestClassifier(n_estimators = 100, criterion='gini', random_state=42)
rf.fit(X_important_train, y_train)
y_pred = rf.predict(X_important_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     backdoor       1.00      1.00      1.00      1500
#         ddos       1.00      1.00      1.00      1489
#    injection       1.00      1.00      1.00      1492
#       normal       1.00      1.00      1.00      7865
#     password       1.00      1.00      1.00      1492
#   ransomware       1.00      1.00      1.00       870
#          xss       1.00      1.00      1.00       605
#
#     accuracy                           1.00     15313
#    macro avg       1.00      1.00      1.00     15313
# weighted avg       1.00      1.00      1.00     15313

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=14,
            min_impurity_decrease=0.0, 
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

# prediction on test set
y_pred=clf.predict(X_test)

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn import tree

plt.figure(figsize=(20,20))
_ = tree.plot_tree(rf.estimators_[0], feature_names=X.columns, filled=True)

# %%
# view the feature scores

feature_scores = pd.Series(clf.feature_importances_, index=X_train.columns).sort_values(ascending=False)

feature_scores
# Out:
# hour_sin              0.197894
# hour_cos              0.180528
# day_name_0            0.165484
# day_name_2            0.153775
# day_name_1            0.140363
# month_sin             0.089065
# month_cos             0.072359
# fridge_temperature    0.000444
# temp_condition        0.000059
# temp_condition        0.000030
# dtype: float64

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[1500    0    0    0    0    0    0]
#  [   0 1489    0    0    0    0    0]
#  [   0    0 1492    0    0    0    0]
#  [   0    0    0 7865    0    0    0]
#  [   0    0    0    0 1492    0    0]
#  [   0    0    0    0    0  870    0]
#  [   0    0    0    0    0    0  605]]
#               precision    recall  f1-score   support
#
#     backdoor       1.00      1.00      1.00      1500
#         ddos       1.00      1.00      1.00      1489
#    injection       1.00      1.00      1.00      1492
#       normal       1.00      1.00      1.00      7865
#     password       1.00      1.00      1.00      1492
#   ransomware       1.00      1.00      1.00       870
#          xss       1.00      1.00      1.00       605
#
#     accuracy                           1.00     15313
#    macro avg       1.00      1.00      1.00     15313
# weighted avg       1.00      1.00      1.00     15313
#
# 1.0

# %%
df
# Out:
#           month_cos  month_sin  hour_sin      hour_cos  fridge_temperature  \
# 0      6.123234e-17        1.0 -1.000000 -1.836970e-16                9.00
# 1      6.123234e-17        1.0 -1.000000 -1.836970e-16                9.25
# 2      6.123234e-17        1.0 -1.000000 -1.836970e-16               12.65
# 3      6.123234e-17        1.0 -1.000000 -1.836970e-16                4.65
# 4      6.123234e-17        1.0 -1.000000 -1.836970e-16               12.65
# ...             ...        ...       ...           ...                 ...
# 59938  6.123234e-17        1.0  0.707107  7.071068e-01                9.85
# 59940  6.123234e-17        1.0  0.707107  7.071068e-01               13.85
# 59941  6.123234e-17        1.0  0.707107  7.071068e-01                5.40
# 59942  6.123234e-17        1.0  0.707107  7.071068e-01                2.90
# 59943  6.123234e-17        1.0  0.707107  7.071068e-01                7.85
#
#        temp_condition  temp_condition  day_name_0  day_name_1  day_name_2  \
# 0                   1               1           0           0           1
# 1                   1               1           0           0           1
# 2                   1               1           0           0           1
# 3                   0               0           0           0           1
# 4                   1               1           0           0           1
# ...               ...             ...         ...         ...         ...
# 59938               1               1           1           0           0
# 59940               1               1           1           0           0
# 59941               0               0           1           0           0
# 59942               0               0           1           0           0
# 59943               1               1           1           0           0
#
#          type
# 0        ddos
# 1        ddos
# 2        ddos
# 3        ddos
# 4        ddos
# ...       ...
# 59938  normal
# 59940  normal
# 59941  normal
# 59942  normal
# 59943  normal
#
# [51043 rows x 11 columns]

# %%
# split dataset
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
X = df.iloc[:,:-1]
y = df["label"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0, stratify =y)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\_libs\index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\_libs\index.pyx:201, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\_libs\index.pyx:209, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\_libs\index.pyx:107, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [51], in <cell line: 5>()
#       3 from sklearn import preprocessing
#       4 X = df.iloc[:,:-1]
# ----> 5 y = df["label"]
#       6 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0, stratify =y)
#       7 print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\masterarbeit\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'label'

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=20, max_depth=10,random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
len(regressor.estimators_)

# %%
from sklearn import tree

plt.figure(figsize=(20,20))
_ = tree.plot_tree(regressor.estimators_[0], feature_names=X.columns, filled=True)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))

# %%
### 3. Model Building  ###

# split dataset
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
X = df.iloc[:,:-1]
y = df["label"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0, stratify =y)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# implement logistic regression
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression(max_iter = 300)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)

# %%
### 4. Model Evaluation  ###
from sklearn import metrics

# confusion matrix
confusion_matrix = metrics.plot_confusion_matrix(reg, X_test, y_test, cmap = "GnBu")
print(confusion_matrix)

# accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))



# ROC curve and AUC
y_pred_proba = reg.predict_proba(X_test)[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test,  y_pred_proba)
plt.plot(fpr,tpr)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
print("AUC:", round(auc,2))

# %%
from sklearn.metrics import f1_score

f1_score(y_test, y_pred)

# %%
# recall
from sklearn.metrics import recall_score

recall_score(y_test, y_pred)

# %%
# precision
from sklearn.metrics import precision_score

precision_score(y_test, y_pred)
